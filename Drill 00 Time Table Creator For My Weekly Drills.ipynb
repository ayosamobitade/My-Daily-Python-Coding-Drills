# %% [markdown]
# # My Organized Time Table For Daily Drills Towards DATA SCIENCE

# %%
# import necessary libraries

import random
import pandas as pd
from datetime import date

# the roundom seed which is the date for new roll out
random.seed(1)

# make a list of 8 random numbers from 1 to 71

#pick 8 random numbers from 1 - 71
drill_list = random.sample(range(1,71), 8)

# multiply the list by three so you can practice a drill atleast three times in a week
new_list = drill_list * 3

# seperate the new_list into periods
period_1 = new_list[0:7]
period_2 = new_list[7:14]
period_3 = new_list[14:21]

# Create a dataframe

# create days of the week list

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"]

# then the dataframe

drill_table = pd.DataFrame(days,columns = ["Day/Period"])

# add other columns to the just created data frame

drill_table["Period 1"] =  period_1
drill_table["Period 2"] =  period_2
drill_table["Period 3"] =  period_3

# set the index of my drill table to Day/Period

drill_table.set_index("Day/Period", inplace = True)
print("\n", drill_table)


#picking the exact date today time table

weekday_map =  {0:"Monday", 1:"Tuesday", 2:"Wednessday", 3:"Thursday", 4:"Friday", 5:"Saturday", 6:"Sunday"}


Today_drill = drill_table[drill_table.index == weekday_map[date.today().weekday()]]

print("\n","\n","DRILLS TO PRACTICE FOR TODAY: ",weekday_map[date.today().weekday()],",", date.today().strftime('%B %d, %Y'), "\n","\n",Today_drill)
# Out:
#              Period 1  Period 2  Period 3
# Day/Period
# Monday            18        42        61
# Tuesday            9        18        42
# Wednesday         33         9        18
# Thursday          16        33         9
# Friday            64        16        33
# Saturday          58        64        16
# Sunday            61        58        64
#
#
#  DRILLS TO PRACTICE FOR TODAY:  Tuesday , December 21, 2021
#
#              Period 1  Period 2  Period 3
# Day/Period
# Tuesday            9        18        42

# %% [markdown]
# # Time table for the R_Programming skill

# %%
# import necessary libraries

import random
import pandas as pd
from datetime import date

# the roundom seed which is the date for new roll out
random.seed(1)

# make a list of 8 random numbers from 1 to 71

#pick 8 random numbers from 1 - 71
drill_list = random.sample(range(1,19), 8)

# multiply the list by three so you can practice a drill atleast three times in a week
new_list = drill_list * 3

# seperate the new_list into periods
period_1 = new_list[0:7]
period_2 = new_list[7:14]


# Create a dataframe

# create days of the week list

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"]

# then the dataframe

drill_table = pd.DataFrame(days,columns = ["Day/Period"])

# add other columns to the just created data frame

drill_table["Period 1"] =  period_1
drill_table["Period 2"] =  period_2


# set the index of my drill table to Day/Period

drill_table.set_index("Day/Period", inplace = True)
print("\n", drill_table)


#picking the exact date today time table

weekday_map =  {0:"Monday", 1:"Tuesday", 2:"Wednessday", 3:"Thursday", 4:"Friday", 5:"Saturday", 6:"Sunday"}


Today_drill = drill_table[drill_table.index == weekday_map[date.today().weekday()]]

print("\n","\n","DRILLS TO PRACTICE FOR TODAY: ",weekday_map[date.today().weekday()],",", date.today().strftime('%B %d, %Y'), "\n","\n",Today_drill)
# Out:
#              Period 1  Period 2
# Day/Period
# Monday             5        12
# Tuesday            3         5
# Wednesday          9         3
# Thursday           2         9
# Friday             8         2
# Saturday          13         8
# Sunday            14        13
#
#
#  DRILLS TO PRACTICE FOR TODAY:  Monday , December 20, 2021
#
#              Period 1  Period 2
# Day/Period
# Monday             5        12

# %% [markdown]
# 1. Data preprocessing kirill
# 2. Regression kiril
# 3. Classification Kirill
# 4. clustring Kirill
# 5. Association rule Kirill
# 6. Reinforcement learning Kiril
# 7. Natural Language Processing Kiril
# 8. Deep Learning Kiril
# 9. Dimentionality Reducibility Kiril
# 10. Model selection and Boosting
# 11. R_basic HVD
# 12. Data visualisation HVD
# 13. Probability hvd
# 14. Inference modeling
# 15. Linear Regression
# 16. productivity tool
# 17. Machine Learning
# 18. Cpstone
# 19. Data wrangling
# 20.
